# %% [markdown]
# # Before you start :
#    - These exercises are related to the Pivot table and correlation lessons.
#    - Keep in mind that you need to use some of the functions you learned in the previous lessons.
#    - All datasets are provided in the `your-code` folder of this lab.
#    - Elaborate your codes and outputs as much as you can.
#    - Try your best to answer the questions and complete the tasks and most importantly enjoy the process!!!

# %% [markdown]
# #### Import all the libraries that are necessary.

# %%
# your answer here
import numpy as np
import pandas as pd

# %% [markdown]
# #### Open the ` Employee.csv` file and name your dataset `employee`.

# %%
# your answer here
employee = pd.read_csv('Employee.csv')
employee.head(10)
# Out:
#      Name Department Education Gender      Title  Years  Salary
# 0    Jose         IT  Bachelor      M    analyst      1      35
# 1   Maria         IT    Master      F    analyst      2      30
# 2   David         HR    Master      M    analyst      2      30
# 3   Sonia         HR  Bachelor      F    analyst      4      35
# 4  Samuel      Sales    Master      M  associate      3      55
# 5     Eva      Sales  Bachelor      F  associate      2      55
# 6  Carlos         IT    Master      M         VP      8      70
# 7   Pedro         IT       Phd      M  associate      7      60
# 8     Ana         HR    Master      F         VP      8      70

# %% [markdown]
# #### What's the mean salary by department?
# Hint : There are 2 ways to do it - one way is with groupby and the other way is with pivot tables. Do it both ways.

# %%
# Method 1
# your answer here
display(employee.groupby(['Department'])['Salary'].mean())
# Out:
# Department
# HR       45.00
# IT       48.75
# Sales    55.00
# Name: Salary, dtype: float64

# %% [markdown]
# #### We want now to group the data by more than one column. Use Pandas pivot table function to select the mean salary by department and title.

# %%
employee.pivot_table(index= ['Department'], values = ['Salary'], aggfunc ={'Salary':'mean'})
# Out:
#             Salary
# Department
# HR           45.00
# IT           48.75
# Sales        55.00

# %%
# your answer here
df = employee.pivot_table(index= ['Department','Title'], values = ['Salary'], aggfunc = {'Salary':'mean'}).reset_index()
df.columns = ['Department','Title', 'Average Salary']
df.head()
# Out:
#   Department      Title  Average Salary
# 0         HR         VP            70.0
# 1         HR    analyst            32.5
# 2         IT         VP            70.0
# 3         IT    analyst            32.5
# 4         IT  associate            60.0

# %% [markdown]
# #### We want to display the number of years of work experience and the salary for each Title. Add Years as a column in your pivot table.
# *Hint: Use Pandas doc(see References in README.md) to explore the pivot_table() arguments*

# %%
# I could add 'Department' but not clear at the question.
# For also "add years" didn't make sense, we already making calculation on that column and it comes back in the result.
df2 = employee.pivot_table(index= ['Title'], values = ['Years', 'Salary'], aggfunc = {'Years':'sum','Salary':'sum'}).reset_index()
# changing the column names
df2.columns = ['Title','Total Salary', 'Total Years']
df2.head()
# Out:
#        Title  Total Salary  Total Years
# 0         VP           140           16
# 1    analyst           130            9
# 2  associate           170           12

# %% [markdown]
# #### We want to know the information about the mean salary and number of employees in each department and for each job title.

# %%
# your answer here
df3 = employee.pivot_table(index= ['Department','Title'], values = ['Salary', 'Name'], aggfunc = {'Salary':'mean','Name':pd.Series.nunique}).reset_index()
df3.columns = ['Department', 'Title', 'No of Employee', 'Average Salary']
df3.head()
# Out:
#   Department      Title  No of Employee  Average Salary
# 0         HR         VP               1            70.0
# 1         HR    analyst               2            32.5
# 2         IT         VP               1            70.0
# 3         IT    analyst               2            32.5
# 4         IT  associate               1            60.0

# %% [markdown]
# #### We want to know for each department and for each job title the Salary's median, minimum, maximum and standard deviation. Comment your results.

# %%
# your answer here
df4 = employee.pivot_table(index= ['Department','Title'], values = ['Salary'], aggfunc = ['median','min','max','std']).reset_index()
df4.columns = ['Department', 'Title', 'Salary Median', 'Minimum Salary', 'Maximum Salary', 'Standard Dev']
df4.head()
# Out:
#   Department      Title  Salary Median  Minimum Salary  Maximum Salary  \
# 0         HR         VP           70.0              70              70
# 1         HR    analyst           32.5              30              35
# 2         IT         VP           70.0              70              70
# 3         IT    analyst           32.5              30              35
# 4         IT  associate           60.0              60              60
#
#    Standard Dev
# 0           NaN
# 1      3.535534
# 2           NaN
# 3      3.535534
# 4           NaN

# %% [markdown]
# #### Based on your comments, fill the missing values with an appropriate value.

# %%
# your answer here
# because there is 1 employee, std is nan >> squareroot of zero. 
# then it is appropriate to fill with zero. Because it"s distance to mean is zero.
df4 = round(df4.fillna(0),2)
df4.head()
# Out:
#   Department      Title  Salary Median  Minimum Salary  Maximum Salary  \
# 0         HR         VP           70.0              70              70
# 1         HR    analyst           32.5              30              35
# 2         IT         VP           70.0              70              70
# 3         IT    analyst           32.5              30              35
# 4         IT  associate           60.0              60              60
#
#    Standard Dev
# 0          0.00
# 1          3.54
# 2          0.00
# 3          3.54
# 4          0.00

# %% [markdown]
# #### The stake holders want to know for each department the number of employees and how much money is spend on salaries. Could you provide that information?

# %%
# your answer here
df5 = employee.pivot_table(index= ['Department'], values = ['Name', 'Salary'], aggfunc = {'Name':pd.Series.nunique,'Salary':'sum'}).reset_index()
# changing the column names
df5.columns = ['Department','No of Employee', 'Total Salary']
df5.head()
# Out:
#   Department  No of Employee  Total Salary
# 0         HR               3           135
# 1         IT               4           195
# 2      Sales               2           110

# %% [markdown]
# #### For each Department and Title, we want to know the the total years of work experience and the mean salary.

# %%
# your answer here
df6 = employee.pivot_table(index= ['Department', 'Title'], values = ['Years', 'Salary'], aggfunc = {'Years':'sum','Salary':'mean'}).reset_index()
df6.columns = ['Department', 'Title', 'Average Salary', 'Total Years']
df6.head()
# Out:
#   Department      Title  Average Salary  Total Years
# 0         HR         VP            70.0            8
# 1         HR    analyst            32.5            6
# 2         IT         VP            70.0            8
# 3         IT    analyst            32.5            3
# 4         IT  associate            60.0            7

# %% [markdown]
# ### Bonus
#
# #### We now want to compute the mean salary after removing the maxima for each Department. Create the appropriate pivot table.
#
# Hint: Write a custom function.

# %%
# your answer here
employee.head(60)
# Out:
#      Name Department Education Gender      Title  Years  Salary
# 0    Jose         IT  Bachelor      M    analyst      1      35
# 1   Maria         IT    Master      F    analyst      2      30
# 2   David         HR    Master      M    analyst      2      30
# 3   Sonia         HR  Bachelor      F    analyst      4      35
# 4  Samuel      Sales    Master      M  associate      3      55
# 5     Eva      Sales  Bachelor      F  associate      2      55
# 6  Carlos         IT    Master      M         VP      8      70
# 7   Pedro         IT       Phd      M  associate      7      60
# 8     Ana         HR    Master      F         VP      8      70

# %%
def mean_no_max(values):
    no_max = []
    for v in values:
        if v == values.max():
            no_max
        else:
            no_max.append(v)
    mean = np.mean(no_max)
    return mean
df_mean_no_max = employee.pivot_table(index=['Department'],values= ['Salary'], aggfunc = ['mean',mean_no_max])
df_mean_no_max
# Out:
# C:\Users\aslis\anaconda3\lib\site-packages\numpy\core\fromnumeric.py:3440: RuntimeWarning: Mean of empty slice.
#   return _methods._mean(a, axis=axis, dtype=dtype,
# C:\Users\aslis\anaconda3\lib\site-packages\numpy\core\_methods.py:189: RuntimeWarning: invalid value encountered in double_scalars
#   ret = ret.dtype.type(ret / rcount)
#              mean mean_no_max
#            Salary      Salary
# Department
# HR          45.00   32.500000
# IT          48.75   41.666667
# Sales       55.00         NaN

# %%
def mean_no_max(values):
    no_max = []
    for x in values:
        if x != max(x):
            no_max.append(x)
    mean = np.mean(no_max)
    return mean

# %%
df_mean_no_max = employee.pivot_table(index=['Department'],values= ['Salary'], aggfunc = ['mean',mean_no_max])
df_mean_no_max
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# File ~\anaconda3\lib\site-packages\pandas\core\groupby\generic.py:900, in DataFrameGroupBy.aggregate(self, func, engine, engine_kwargs, *args, **kwargs)
#     899 try:
# --> 900     result = gba.agg()
#     902 except ValueError as err:
#
# File ~\anaconda3\lib\site-packages\pandas\core\apply.py:171, in Apply.agg(self)
#     169 elif is_list_like(arg):
#     170     # we require a list, but not a 'str'
# --> 171     return self.agg_list_like()
#     173 if callable(arg):
#
# File ~\anaconda3\lib\site-packages\pandas\core\apply.py:412, in Apply.agg_list_like(self)
#     411 if not len(results):
# --> 412     raise ValueError("no results")
#     414 if len(failed_names) > 0:
#
# ValueError: no results
#
# During handling of the above exception, another exception occurred:
#
# TypeError                                 Traceback (most recent call last)
# Input In [30], in <cell line: 1>()
# ----> 1 df_mean_no_max = employee.pivot_table(index=['Department'],values= ['Salary'], aggfunc = ['mean',mean_no_max])
#       2 df_mean_no_max
#
# File ~\anaconda3\lib\site-packages\pandas\core\frame.py:8038, in DataFrame.pivot_table(self, values, index, columns, aggfunc, fill_value, margins, dropna, margins_name, observed, sort)
#    8021 @Substitution("")
#    8022 @Appender(_shared_docs["pivot_table"])
#    8023 def pivot_table(
#    (...)
#    8034     sort=True,
#    8035 ) -> DataFrame:
#    8036     from pandas.core.reshape.pivot import pivot_table
# -> 8038     return pivot_table(
#    8039         self,
#    8040         values=values,
#    8041         index=index,
#    8042         columns=columns,
#    8043         aggfunc=aggfunc,
#    8044         fill_value=fill_value,
#    8045         margins=margins,
#    8046         dropna=dropna,
#    8047         margins_name=margins_name,
#    8048         observed=observed,
#    8049         sort=sort,
#    8050     )
#
# File ~\anaconda3\lib\site-packages\pandas\core\reshape\pivot.py:76, in pivot_table(data, values, index, columns, aggfunc, fill_value, margins, dropna, margins_name, observed, sort)
#      74 keys = []
#      75 for func in aggfunc:
# ---> 76     _table = __internal_pivot_table(
#      77         data,
#      78         values=values,
#      79         index=index,
#      80         columns=columns,
#      81         fill_value=fill_value,
#      82         aggfunc=func,
#      83         margins=margins,
#      84         dropna=dropna,
#      85         margins_name=margins_name,
#      86         observed=observed,
#      87         sort=sort,
#      88     )
#      89     pieces.append(_table)
#      90     keys.append(getattr(func, "__name__", func))
#
# File ~\anaconda3\lib\site-packages\pandas\core\reshape\pivot.py:165, in __internal_pivot_table(data, values, index, columns, aggfunc, fill_value, margins, dropna, margins_name, observed, sort)
#     162     values = list(values)
#     164 grouped = data.groupby(keys, observed=observed, sort=sort)
# --> 165 agged = grouped.agg(aggfunc)
#     166 if dropna and isinstance(agged, ABCDataFrame) and len(agged.columns):
#     167     agged = agged.dropna(how="all")
#
# File ~\anaconda3\lib\site-packages\pandas\core\groupby\generic.py:906, in DataFrameGroupBy.aggregate(self, func, engine, engine_kwargs, *args, **kwargs)
#     903     if "no results" not in str(err):
#     904         # raised directly by _aggregate_multiple_funcs
#     905         raise
# --> 906     result = self._aggregate_frame(func)
#     908 else:
#     909     sobj = self._selected_obj
#
# File ~\anaconda3\lib\site-packages\pandas\core\groupby\generic.py:956, in DataFrameGroupBy._aggregate_frame(self, func, *args, **kwargs)
#     953 if self.axis == 0:
#     954     # test_pass_args_kwargs_duplicate_columns gets here with non-unique columns
#     955     for name, data in self:
# --> 956         fres = func(data, *args, **kwargs)
#     957         result[name] = fres
#     958 else:
#     959     # we get here in a number of test_multilevel tests
#
# Input In [29], in mean_no_max(values)
#       4     if x != max(x):
#       5         no_max.append(x)
# ----> 6 mean = np.mean(no_max)
#       7 return mean
#
# File <__array_function__ internals>:5, in mean(*args, **kwargs)
#
# File ~\anaconda3\lib\site-packages\numpy\core\fromnumeric.py:3440, in mean(a, axis, dtype, out, keepdims, where)
#    3437     else:
#    3438         return mean(axis=axis, dtype=dtype, out=out, **kwargs)
# -> 3440 return _methods._mean(a, axis=axis, dtype=dtype,
#    3441                       out=out, **kwargs)
#
# File ~\anaconda3\lib\site-packages\numpy\core\_methods.py:179, in _mean(a, axis, dtype, out, keepdims, where)
#     176         dtype = mu.dtype('f4')
#     177         is_float16_result = True
# --> 179 ret = umr_sum(arr, axis, dtype, out, keepdims, where=where)
#     180 if isinstance(ret, mu.ndarray):
#     181     ret = um.true_divide(
#     182             ret, rcount, out=ret, casting='unsafe', subok=False)
#
# TypeError: cannot perform reduce with flexible type

# %%
def mean_no_max(values):
        values = sorted(values)
        values = values[:len(values)-1]
        mean = np.mean(values)
        return mean

# %%
abc = employee.pivot_table(index=['Department'],values= ['Salary'], aggfunc = ['mean',mean_no_max])
abc
# Out:
#              mean mean_no_max
#            Salary      Salary
# Department
# HR          45.00   32.500000
# IT          48.75   41.666667
# Sales       55.00   55.000000
